# %%
# !tree /F
# Out:
# Folder PATH listing
# Volume serial number is 0041-8F04
# C:.
# ³   .gitignore
# ³   README.md
# ³   Untitled.ipynb
# ³
# ÃÄÄÄ.ipynb_checkpoints
# ³       README-checkpoint.md
# ³       Untitled-checkpoint.ipynb
# ³
# ÃÄÄÄdata
# ³   ³   cv_scores.csv
# ³   ³   df_diabetic.csv
# ³   ³   df_model.csv
# ³   ³   diabetic_data.csv
# ³   ³   IDS_mapping.csv
# ³   ³
# ³   ÀÄÄÄ.ipynb_checkpoints
# ³           IDS_mapping-checkpoint.csv
# ³
# ÀÄÄÄnotebooks
#     ³   eda.ipynb
#     ³   feature_engineering_selection.ipynb
#     ³   preprocessing.ipynb
#     ³   tuning.ipynb
#     ³
#     ÀÄÄÄ.ipynb_checkpoints
#             eda-checkpoint.ipynb
#             feature_engineering_selection-checkpoint.ipynb
#             preprocessing-checkpoint.ipynb
#             tuning-checkpoint.ipynb
